# %% [markdown]
# # Music Collage Homework
#
# ## Hint:
# 1. You should just need to copy functions from Lab 6 & Lab 7 to complete this assignment. You just got to know how functions are **defined** and **called**.
# 2. You can test your code by creating sounds using `makeSound` and playing them with `play`.
# 3. Feel free to use any other sounds that you like!

# %%
# %pip install siena_mls
from JES import *
from random import *

# Comments here 

def soundCollage():
  # read in original sounds from files (use your own filenames)
  s1 = makeSound("sound1.wav")
  s2 = makeSound("sound2.wav")
  
  canvasLen = getLength(s1) + getLength(s2)
  canvas = makeEmptySound(canvasLen)  

  # The code below copies in the two original files, but
  # it does not put any silence between them. 
  copy(s1, canvas, 0)
  copy(s2, canvas, getLength(s1))
    
  #copy in three alterations, with silence between them...
  
  #play the final sound
  play(canvas)

# all functions above
################
# test code below

soundCollage()
