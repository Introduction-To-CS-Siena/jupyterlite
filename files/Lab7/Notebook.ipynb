# %% [markdown]
# # Lab 7
# ## Mixing it Up _like a DJ!_
#
# ### Pleae read the instruction manual and use this notebook for python work.

# %%
# %pip install siena_mls
from JES import *
